# %% [markdown]
# # Translate instructions to basis gates
#
# Aside from choosing a layout and routing configuration, translating the instructions of a quantum circuit into the native basis gates of a backend is one of the most complex tasks that the transpiler must take on.  This type of task is executed in several stages of the transpiler and is primarily powered by the [`UnitarySynthesis`](../api/qiskit/qiskit.transpiler.passes.UnitarySynthesis) pass.

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService()
backend = service.backend("ibm_brisbane")

# %%
pm = generate_preset_pass_manager(optimization_level=3, backend=backend)

# %%
pm.init.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3151x756>

# %%
pm.layout.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2553x827>

# %%
pm.routing.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2156x731>

# %%
pm.translation.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3045x439>

# %%
pm.optimization.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1925x1313>

# %%
pm.scheduling.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=756x439>
